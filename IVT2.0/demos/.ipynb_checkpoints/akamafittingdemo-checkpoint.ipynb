# %% [markdown]
# <h1>Fitting IVT mechanistic model to Akama dataset<h1>

# %% [markdown]
# In this notebook, we will be showing how the figures in our paper were generated. We will be doing the following
#
#     1. Performing local MAP optimization to fit our model to the dataset of Akama et al.
#     2. Using a linearized model approximation to estimate a parameter covariance matrix.
#     3. Visualizing model fitting by plotting against fitting dataset
#     4. Validating our model on new data (without fitting parameters)

# %% [markdown]
# <b>1. Importing required packages<b>

# %%
using Pkg
Pkg.activate("../IVTmodel")
Pkg.instantiate()
include("../modules/IVTmodel.jl")
# Out:
#   Activating project at `C:\Users\ChemeGrad2021\Documents\Braatz Group\MRNA Synthesis\Published code\IVT2.0\IVTmodel`
# Precompiling project...
#   ? Metrics
# plotMg2PPiphasediagram (generic function with 1 method)

# %%
include("../modules/IVTmodel.jl")
# Out:
# plotMg2PPiphasediagram (generic function with 1 method)

# %% [markdown]
# <b>2: Setting up model and importing data<b>
#
# The following cell creates an object representing the parameters used in our model, whether they are fitted parameters or not, and their Bayesian priors.
#
# We also import required data for fitting and validation.

# %%
#Generates settings for parameters used
fittingmodel = setupmodel_IVT4()
#Imports calibration data from csv files
modeldata = importakamadata()#Note: Data for NTP curves 4 and 5 multiplied by 1.5 to make more consistant
osumidata = importosumidata()
ourpHdata = importosumidata(phfilename = "../data/pH/ourpH.csv")
#Imports PPiase validation data
PPiasedata = importakamaPPiasedata();
# Out:
# Model has 24 fitted parameters, 16 of which have a bayesian prior

# %% [markdown]
# <b>3: Optimizing Model<b>
#
# We next fit the model to the Akama data set using MAP estimation. While in our work multistart optimization was used for this nonconvex problem, we use a local optimization here for simplicity. We will use a manually selected starting point that is near the optimum but not optimal.

# %%
#Start at a manually selected warm start point
modorigin = [
  3.93#k_i_akama
  3.93#k_i_guo
  5.13#k_e_akama
  5.13#k_e_guo
  #3.71
  2.30#k_on
  log10(0.0006722601121132597)
  log10(0.0007918240342381915)
  log10(10.0)#nMg
  -3.1210353022517765#kippi
  log10(exp(4.0))#K_Mg
  log10(exp(2.86))#K_uo
  #-6.224527413308775
  #-3.8
 -4.50
 -7.5
 -9.2
 log10(15.0)
 0.0
 #log10(0.0208)
 # 0 #If using "ppiaseuncertainty = true" uncomment this line
 #-3.6695 #If using "ppiaseuncertainty = true" uncomment this line
 -0.26
  1.65
  4.47
  #6.91
  #2.08
  #9.02
  #3.30
  #6.91
  #2.08
  #3.32#KHMgPPi
  4.0227#KMgNTP
  #1.6049#KMg2NTP
  6.904370333455767#5.23
  3.99#Mg2PPi
 -3.95
]


modorigin = [
  4.195496721933051#k_i_akama
  4.195496721933051#k_i_guo
  5.580537540835233#k_e_akama
  5.724393534884756#k_e_guo
  2.30#k_on
 -3.7126139599282033
 -4.132894306607353
  log10(10.0)#nMg
  -3.1210353022517765#kippi
  log10(exp(4.0))#K_Mg
  log10(exp(2.86))#K_uo
 -7.528892114474933
 -9.283657218610035
  1.1584762469701004
  0.0#gamma
  0.4918949817994031
  1.6471707660497328
  4.654587904073317
  3.32
  4.226535555197134
 # 1.8481863799690796
  5.303909786365148
  3.983606246066889
 -3.903933681060077]

modoriginparams = fullparameterset(fittingmodel,modorigin)
akama_pHresidual = (model,data,parameters) -> akamaresidual(model,data,osumidata,parameters)
printresidual(fittingmodel,modeldata,osumidata,modorigin)
# Out:
# Total Residual:                        5616.5
# Components of residual:
# Concentration Trajectories (Figure 2): 2596.6
# Initial Reaction Rate (Figure 3A):     2530.8
# Mg2PPi solubility (Figure 3B):         204.3
# Parameter priors:                      225.1
# pH Effect Data:                        59.7

# %%
guoresidual = (model,data,parameters) -> customresidualeval(model,data,osumidata,"../data/external/guo/guofig1.csv",parameters; seperateDNA = true, OAccounterion = false)
# Out:
# #2185 (generic function with 1 method)

# %%
guoresidual(fittingmodel, modeldata,modorigin)
# Out:
# 6725.343416733008

# %% [markdown]
# We then optimize the model and calculate a covariance matrix. Note that the loss should be decreasing until a tolerance is reached.

# %%
#optim=localopt(fittingmodel, modeldata,300,modorigin,akama_pHresidual,verbose = true)
optim=localopt(fittingmodel, modeldata,300,modorigin,guoresidual,verbose = true)
fittedparamslist = optim[4]
fittedparams = fullparameterset(fittingmodel,fittedparamslist)
#covariancemat = getcovariancematrix(fittingmodel,modeldata,osumidata,fittedparamslist);
covariancemat = getcovariancematrix(fittingmodel,modeldata,osumidata,fittedparamslist,customfile = true,customfilename = "../data/external/guo/guofig1.csv", NaperNTP = 3.77, seperateDNA = true, OAccounterion = false);
writedlm( "../outputs/fittedparameters.csv",  fittedparamslist, ',')
writedlm( "../outputs/covariancematrix.csv",  covariancemat, ',')
printresidual(fittingmodel,modeldata,osumidata,fittedparamslist)
# Out:
# 6725.334378939655
# 34343.4406765423
# 6599.7160564844635
# 4116.4549900493985
# 4148.622466430116
# 3851.870680621808
# 3799.9671141225135
# 3729.0802638263394
# 3596.9685100849792
# 3394.1653844807142
# 3082.339205923339
# 2869.536061679346
# 2757.2758123501426
# 2646.4203691897574
# 2503.1679615565763
# 2755.5112865130777
# 2453.762575568163
# 2425.689124022626
# 2414.4769831629
# 2401.42738144532
# 2373.9008229005117
# 2319.673912076322
# 2242.762262482156
# 2212.8359410936164
# 2181.1561675680514
# 2171.999230459354
# 2165.727825418035
# 2158.965008297312
# 2156.361614118628
# 2146.28063424464
# 2122.3689980715317
# 2109.9606518018154
# 2093.1720509944525
# 2082.48265317827
# 2074.1503784085317
# 2066.858899064465
# 2033.440396006276
# 2002.9167827223357
# 1983.1462306507224
# 1974.8308671038767
# 1969.8377001455428
# 1967.6791558900745
# 1966.1860409175029
# 1963.0888635460242
# 1954.6398066394327
# 1928.2096947041273
# 1900.8965231549514
# 1876.9375235673986
# 1877.7688233988079
# 1868.959186405476
# 1865.5431066681435
# 1862.278957640825
# 1861.072370935186
# 1859.6206245116082
# 1856.7826704150543
# 1853.8946618744587
# 1844.2949074883886
# 1833.4059584163301
# 1816.6049440862207
# 1799.7286631790187
# 1791.481560501751
# 1784.9227608495817
# 1780.9470155922072
# 1770.6176189624443
# 1753.396009381817
# 1725.5756066898634
# 1709.2041052344532
# 1733.3021497336158
# 1705.4728278233565
# 1701.398393020896
# 1698.3623885299066
# 1696.0001293904616
# 1695.8276649184804
# 70990.09857885478
# 1717.9173233042056
# 1695.8201826355887
# 29733.79323549822
# 1945.7595471618374
# 1695.7706080304117
# 1695.67993790538
# 2476.005662834623
# 1692.7666342193384
# 71129.50903927264
# 1715.616773625985
# 1692.7644246332115
# 30652.801820447487
# 1946.8549648760206
# 1692.697580040116
# 1690.518121306746
# 2008.724173692628
# 1689.242687733431
# 1870.6042228519036
# 1684.335131274682
# 2371.645597157765
# 1681.6923048534106
# 1700.2870825705963
# 1675.405503401639
# 1671.8014213938823
# 1680.3900527915516
# 1669.235070804038
# 1673.3573762376095
# 1667.1512111190718
# 1664.4988209633227
# 1662.8556606180582
# 1661.3514359501578
# 1657.9755982312151
# 1656.187642134887
# 1654.638444319533
# 1654.2692721641029
# 1654.098843213721
# 1653.936799678428
# 1653.656108965457
# 1653.08638575735
# 1652.4463885825708
# 1651.9451193064613
# 1651.5822337675806
# 1651.3123415705281
# 1651.2142272068818
# 1651.192528209011
# 1651.1771473754459
# 1651.1483848519965
# 1651.094482799462
# 1651.0164094747142
# 1650.9763854029075
# 1650.955994957275
# 1650.9488221215402
# got 1650.9488221215402 at [9515.55420169179, 3082.423470068931, 140527.44977783356, 1.2189786891581425e6, 759.7589616607329, 0.00022450030561707742, 5.7227736831920725e-8, 25.000000000000007, 3.589068153508439e-5, 42.76395374998287, 13.869327180460084, 6.443103817836598e-8, 3.516521992845034e-10, 11.988860854635575, 1.0, 4.4237556205268165, 44.85434076673148, 43725.35864980659, 1439.1638798826975, 9498.440917084807, 132219.962105288, 6240.878874481132, 0.00012515037917951635] after 126 iterations (returned MAXTIME_REACHED)
# Total Residual:                        1082.1
# Components of residual:
# Concentration Trajectories (Figure 2): 423.6
# Initial Reaction Rate (Figure 3A):     206.0
# Mg2PPi solubility (Figure 3B):         209.9
# Parameter priors:                      154.6
# pH Effect Data:                        88.0

# %% [markdown]
# We can investigate the source of the loss between the datasets used in our calibration set. In this case, residuals are roughly proportional to the amount of "information" we get from each source.

# %% [markdown]
# <b>4: Plotting Figures from Paper - Fitting Data<b>
#
# Now that we have have successfully fit a set of parameters to our model, we can think about plotting our data alongside our model predictions.

# %%
println(log10.(fittedparams))
println(fittedparams.k_i*1000/fittedparams.k_e)
println(1800*1000/(10^(4.72)))
# Out:
# (k_dT7 = -Inf, k_i = 3.978434087392085, k_i_guo = 3.488892302805691, k_e = 5.14776116497171, k_e_guo = 6.085996113114752, k_off = 3.635483746814912, k_on = 2.880675831459254, K_1 = -3.64878306344587, K_2 = -7.24239342866514, nMg = 1.3979400086720377, Ki_PPi = -4.445018294686652, K_Mg = 1.6310778511770796, K_u0 = 1.142055393380355, K_a = -7.190904870803226, K_b = -9.453886662100604, k_pH = 1.0787779197086296, gamma = 0.0, theta = -1.6819366650372385, K_ds = 0.0, kPPiase = 0.0, KMPPiase = -3.669586226650809, k_precip = 0.6457911274313257, B = 1.6518044781452683, k_d = 4.640733380391838, K_HNTP = 6.4867, K_HMgNTP = 2.00832, K_HPPi = 9.02, K_HMgPPi = 3.1581102505567267, K_H2PPi = 6.26, K_H2MgPPi = 2.11, K_MgNTP = 3.9776523256389678, K_Mg2NTP = 1.6049, K_MgPPi = 5.121297028354618, K_Mg2PPi = 3.795245753698502, Mg2PPi_eq = -3.902567830232169, K_MgPi = 1.6354428, K_HPi = 6.620343, K_NaPi = 0.77, K_NaNTP = 1.16)
# 67.71313516850533
# 34.29829292333847

# %%
plt = revision1plot1(fittingmodel,modeldata, fittedparams, covariancemat, true,false)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/akamamain.png")
plt

# %%
plt = revision1plot2(fittingmodel,modeldata, fittedparams, covariancemat, true,false)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/akamarate.png")
plt

# %%
#Note: Following effective T7 concentration from above
preground3filename = "../data/external/guo/guokinetics.csv"
plt = plotfromcsv(fittingmodel,fittedparamslist,covariancemat,preground3filename,range = [1,2,3,4],plotsize = (600,450),dataerrorbars = true, multiplot = false,maximumyield = false, precip = true, NaperNTP = 3.77, seperateDNA = true, OAccounterion = false)

# %%
plt = pHplotting(fittingmodel,osumidata, fittedparamslist, covariancemat)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/osumipH.png")
plt

# %%
scatter!(plt,ourpHdata[:,1],ourpHdata[:,2],yerror = 2,color = :red,label= "Our Data (Validation)")
savefig(plt,"../figures/GM6_27/ourpH.png")
plt

# %% [markdown]
# <b>5: Plotting Figures from Paper - Validation Data<b>
#
# Finally, we can apply our model to new data. See the main body of our paper for a complete description of what this data represents.

# %%
plt= plotakamaPPiase(PPiasedata, fittedparams, covariancemat,fittingmodel)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/ppiaseval.png")
plt

# %%
df = CSV.read("../data/external/guo/guoMgNTP.csv", DataFrame)
guodata = Matrix(df)

df = CSV.read("../data/akama_data/akamaMgNTP.csv", DataFrame)
akamadata = Matrix(df);

# %%
log10(exp(4.0))
# Out:
# 1.7371779276130073

# %%
testlist = fittedparamslist
# Out:
# 23-element Vector{Float64}:
#   3.978434087392085
#   3.488892302805691
#   5.14776116497171
#   6.085996113114752
#   2.880675831459254
#  -3.64878306344587
#  -7.24239342866514
#   1.3979400086720377
#  -4.445018294686652
#   1.6310778511770796
#   1.142055393380355
#  -7.190904870803226
#  -9.453886662100604
#   1.0787779197086296
#   6.245583772218893e-27
#   0.6457911274313257
#   1.6518044781452683
#   4.640733380391838
#   3.1581102505567267
#   3.9776523256389678
#   5.121297028354618
#   3.795245753698502
#  -3.902567830232169

# %%
plt = plotbyMg(fittingmodel,akamadata,testlist, covariancemat;showconfidence = false,T7RNAP = 1e-7, DNA = 7.4, finaltime = 5/60, PPiase = 0, stoich = (231,246,189,202), datastddev = 0.03,Mgrange = (2e-3,30e-3), nmc = 500, OAccounterion = true)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/akamaratetrans.png")
plt

# %%
plt = plotbyMg(fittingmodel,guodata,testlist , covariancemat;showconfidence = false, seperateDNA = true, OAccounterion = false, showpredictions = true)
plot!(dpi = 400)
savefig(plt,"../figures/GM6_27/guomain.png")
plt

# %% [markdown]
# <b>Validation?<b>

# %%
pfizerls = fittedparamslist
pfizerfilename = "../data/external/pfizer/pfizerNTP.csv"
plt = plotfromcsv(fittingmodel,pfizerls,covariancemat,pfizerfilename,range = [1,2,3,4],plotsize = (600,450),dataerrorbars = true, multiplot = false,maximumyield = false, precip = true, seperateDNA = true)

# %%
arrantals = fittedparamslist
arrantafilename = "../data/arranta/batch_COVID_Fluc/arranta_COVID_Fluc_raman_RNA.csv"
#arrantafilename = "../data/arranta/batch_COVID_Fluc/arranta_COVID_Fluc_nd_pH.csv"

plt = plotfromcsv(fittingmodel,arrantals,covariancemat,arrantafilename,range = [9],plotsize = (600,450),dataerrorbars = true, multiplot = false,maximumyield = false, precip = true, seperateDNA = true, BufferperNTP = 3.4, NaperNTP = 1.2, OAccounterion = false)
#plot!(ylims = (6,8))

# %%
preground3filename = "../data/external/guo/guokinetics.csv"
plt = plotfromcsv(fittingmodel,fittedparamslist,covariancemat,preground3filename,range = [2,3,4],plotsize = (600,450),dataerrorbars = true, multiplot = false,maximumyield = false, precip = true, NaperNTP = 3.77, seperateDNA = true, OAccounterion = false)
